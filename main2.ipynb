# %%
import pandas as pd

df = pd.read_csv("breast.csv", low_memory=False)

# %%
df.shape
# Out:
# (712319, 149)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
missing_values = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100

# %%
missing_percent
# Out:
# CASENUM                   0.000000
# REG                       0.000000
# MAR_STAT                  3.934894
# RACE                      0.307868
# ORIGIN                    0.510165
# NHIA                      0.000000
# SEX                       0.000000
# AGE_DX                    0.005475
# YR_BRTH                   0.005475
# SEQ_NUM                   0.002948
# DATE_mo                   0.000000
# DATE_yr                   0.000000
# SITEO2V                   0.000000
# LATERAL                   0.000000
# HISTO2V                   0.000000
# BEHO2V                    0.000000
# HISTO3V                   0.000000
# BEHO3V                    0.000000
# GRADE                     0.000000
# DX_CONF                   0.602258
# REPT_SRC                  0.000000
# EOD10_SZ                 59.656137
# EOD10_EX                 53.376928
# EOD10_PE                100.000000
# EOD10_ND                 53.376928
# EOD10_PN                 24.518650
# EOD10_NE                 25.300603
# EOD13                    87.602465
# EOD2                     98.070668
# EOD4                     89.810885
# EODCODE                  28.858278
# TUMOR_1V                 63.527717
# TUMOR_2V                 63.841200
# TUMOR_3V                100.000000
# CS_SIZE                  74.012065
# CS_EXT                   71.786236
# CS_NODE                  71.984462
# CS_METS                  71.141722
# CS_SSF1                  72.532952
# CS_SSF2                  72.670952
# CS_SSF3                  71.141722
# CS_SSF4                  71.141722
# CS_SSF5                  71.141722
# CS_SSF6                  71.141722
# CS_SSF25                 71.141722
# D_AJCC_T                 72.305386
# D_AJCC_N                 71.981795
# D_AJCC_M                 71.783428
# D_AJCC_S                 72.331076
# D_SSG77                  71.141722
# D_SSG00                  71.141722
# D_AJCC_F                 71.141722
# D_SSG77F                 71.141722
# D_SSG00F                 71.141722
# CSV_ORG                  71.141722
# CSV_DER                  71.141722
# CSV_CUR                  71.141722
# SURGPRIM                 51.045950
# SCOPE                    67.867346
# SURGOTH                  67.867346
# SURGNODE                 83.120765
# RECONST                  83.178604
# NO_SURG                   0.000000
# RADIATN                   0.000000
# RAD_BRN                   0.000000
# RAD_SURG                  0.090549
# SS_SURG                  48.954050
# SCOPE02                  83.178604
# SRGOTH02                 83.178604
# REC_NO                    0.000000
# O_SITAGE                 99.981329
# O_SEQCON                 99.772714
# O_SEQLAT                 99.388897
# O_SURCON                 99.975994
# O_SITTYP                 99.702521
# H_BENIGN                 99.963499
# O_RPTSRC                 99.970238
# O_DFSITE                 99.979925
# O_LEUKDX                 99.984417
# O_SITBEH                 99.979925
# O_EODDT                  99.994946
# O_SITEOD                 99.987927
# O_SITMOR                 99.965746
# TYPEFUP                   0.000000
# AGE_REC                   0.005475
# SITERWHO                  0.000000
# ICDOTO9V                  0.000000
# ICDOT10V                  0.000000
# ICCC3WHO                 15.221130
# ICCC3XWHO                15.221130
# BEHANAL                   0.000000
# HISTREC                   0.000000
# BRAINREC                  0.000000
# CS0204SCHEMA              0.000000
# RAC_RECA                  0.391538
# RAC_RECY                  0.391538
# NHIAREC                   0.000000
# HST_STGA                  0.000000
# AJCC_STG                 53.376928
# AJ_3SEER                 53.376928
# SSG77                    81.747082
# SSG2000                  90.082252
# NUMPRIMS                  0.000000
# FIRSTPRM                  0.000000
# STCOUNTY                  0.000000
# ICD_5DIG                  0.000000
# CODKM                     0.000000
# STAT_REC                  0.000000
# IHS                      18.904311
# HIST_SSG_2000            51.045950
# AYA_RECODE                0.000000
# LYMPHOMA_RECODE           0.000000
# DTH_CLASS                 0.000000
# O_DTH_CLASS               0.000000
# EXTEVAL                  74.672303
# NODEEVAL                 74.672022
# METSEVAL                 74.674268
# INTPRIM                   0.000000
# ERSTATUS                  0.000000
# PRSTATUS                  0.000000
# CSSCHEMA                  0.000000
# CS_SSF8                 100.000000
# CS_SSF10                100.000000
# CS_SSF11                100.000000
# CS_SSF13                100.000000
# CS_SSF15                 93.082734
# CS_SSF16                100.000000
# VASINV                  100.000000
# SRV_TIME_MON              0.000000
# SRV_TIME_MON_FLAG         0.000000
# SRV_TIME_MON_PA           0.000000
# SRV_TIME_MON_FLAG_PA      0.000000
# INSREC_PUB               81.321290
# DAJCC7T                  92.673507
# DAJCC7N                  92.580571
# DAJCC7M                  92.403263
# DAJCC7STG                92.630409
# ADJTM_6VALUE             24.518650
# ADJNM_6VALUE             24.518650
# ADJM_6VALUE              24.518650
# ADJAJCCSTG               24.518650
# CS7SITE                  94.156129
# CS9SITE                 100.000000
# CS12SITE                100.000000
# HER2                      0.000000
# BRST_SUB                  0.000000
# PLC_BRTH_CNTRY            0.000000
# PLC_BRTH_STATE            0.000000
# ANNARBOR                  0.000000
# dtype: float64

# %%
df = df.dropna(thresh=len(df) * 0.8, axis=1)

# %%
df.shape
# Out:
# (712319, 65)

# %%
object_cols = df.select_dtypes(include=['object']).columns.tolist()
object_cols
# Out:
# ['SITEO2V', 'ICDOT10V', 'PLC_BRTH_CNTRY', 'PLC_BRTH_STATE']

# %%
df = pd.get_dummies(df, columns=object_cols, drop_first=True)

# %%
missing_percent = (df.isnull().sum() / len(df)) * 100
missing_percent
# Out:
# CASENUM                  0.000000
# REG                      0.000000
# MAR_STAT                 3.934894
# RACE                     0.307868
# ORIGIN                   0.510165
# NHIA                     0.000000
# SEX                      0.000000
# AGE_DX                   0.005475
# YR_BRTH                  0.005475
# SEQ_NUM                  0.002948
# DATE_mo                  0.000000
# DATE_yr                  0.000000
# LATERAL                  0.000000
# HISTO2V                  0.000000
# BEHO2V                   0.000000
# HISTO3V                  0.000000
# BEHO3V                   0.000000
# GRADE                    0.000000
# DX_CONF                  0.602258
# REPT_SRC                 0.000000
# NO_SURG                  0.000000
# RADIATN                  0.000000
# RAD_BRN                  0.000000
# RAD_SURG                 0.090549
# REC_NO                   0.000000
# TYPEFUP                  0.000000
# AGE_REC                  0.005475
# SITERWHO                 0.000000
# ICDOTO9V                 0.000000
# ICCC3WHO                15.221130
# ICCC3XWHO               15.221130
# BEHANAL                  0.000000
# HISTREC                  0.000000
# BRAINREC                 0.000000
# CS0204SCHEMA             0.000000
# RAC_RECA                 0.391538
# RAC_RECY                 0.391538
# NHIAREC                  0.000000
# HST_STGA                 0.000000
# NUMPRIMS                 0.000000
# FIRSTPRM                 0.000000
# STCOUNTY                 0.000000
# ICD_5DIG                 0.000000
# CODKM                    0.000000
# STAT_REC                 0.000000
# IHS                     18.904311
# AYA_RECODE               0.000000
# LYMPHOMA_RECODE          0.000000
# DTH_CLASS                0.000000
# O_DTH_CLASS              0.000000
# INTPRIM                  0.000000
# ERSTATUS                 0.000000
# PRSTATUS                 0.000000
# CSSCHEMA                 0.000000
# SRV_TIME_MON             0.000000
# SRV_TIME_MON_FLAG        0.000000
# SRV_TIME_MON_PA          0.000000
# SRV_TIME_MON_FLAG_PA     0.000000
# HER2                     0.000000
# BRST_SUB                 0.000000
# ANNARBOR                 0.000000
# SITEO2V_C501             0.000000
# SITEO2V_C502             0.000000
# SITEO2V_C503             0.000000
# SITEO2V_C504             0.000000
# SITEO2V_C505             0.000000
# SITEO2V_C506             0.000000
# SITEO2V_C508             0.000000
# SITEO2V_C509             0.000000
# ICDOT10V_C169            0.000000
# ICDOT10V_C349            0.000000
# ICDOT10V_C419            0.000000
# ICDOT10V_C435            0.000000
# ICDOT10V_C445            0.000000
# ICDOT10V_C500            0.000000
# ICDOT10V_C501            0.000000
# ICDOT10V_C502            0.000000
# ICDOT10V_C503            0.000000
# ICDOT10V_C504            0.000000
# ICDOT10V_C505            0.000000
# ICDOT10V_C506            0.000000
# ICDOT10V_C508            0.000000
# ICDOT10V_C509            0.000000
# ICDOT10V_C73             0.000000
# ICDOT10V_D035            0.000000
# ICDOT10V_D045            0.000000
# ICDOT10V_D050            0.000000
# ICDOT10V_D057            0.000000
# ICDOT10V_D059            0.000000
# PLC_BRTH_CNTRY_AGO       0.000000
# PLC_BRTH_CNTRY_ALB       0.000000
# PLC_BRTH_CNTRY_ARG       0.000000
# PLC_BRTH_CNTRY_ASM       0.000000
# PLC_BRTH_CNTRY_AUS       0.000000
# PLC_BRTH_CNTRY_AUT       0.000000
# PLC_BRTH_CNTRY_BEL       0.000000
# PLC_BRTH_CNTRY_BGD       0.000000
# PLC_BRTH_CNTRY_BGR       0.000000
# PLC_BRTH_CNTRY_BHS       0.000000
# PLC_BRTH_CNTRY_BLR       0.000000
# PLC_BRTH_CNTRY_BLZ       0.000000
# PLC_BRTH_CNTRY_BMU       0.000000
# PLC_BRTH_CNTRY_BOL       0.000000
# PLC_BRTH_CNTRY_BRA       0.000000
# PLC_BRTH_CNTRY_CAN       0.000000
# PLC_BRTH_CNTRY_CHE       0.000000
# PLC_BRTH_CNTRY_CHL       0.000000
# PLC_BRTH_CNTRY_CHN       0.000000
# PLC_BRTH_CNTRY_COD       0.000000
# PLC_BRTH_CNTRY_COK       0.000000
# PLC_BRTH_STATE_NJ        0.000000
# PLC_BRTH_STATE_NM        0.000000
# PLC_BRTH_STATE_NN        0.000000
# PLC_BRTH_STATE_NV        0.000000
# PLC_BRTH_STATE_NY        0.000000
# PLC_BRTH_STATE_OH        0.000000
# PLC_BRTH_STATE_OK        0.000000
# PLC_BRTH_STATE_ON        0.000000
# PLC_BRTH_STATE_OR        0.000000
# PLC_BRTH_STATE_PA        0.000000
# PLC_BRTH_STATE_PP        0.000000
# PLC_BRTH_STATE_PR        0.000000
# PLC_BRTH_STATE_PW        0.000000
# PLC_BRTH_STATE_QC        0.000000
# PLC_BRTH_STATE_RI        0.000000
# PLC_BRTH_STATE_SC        0.000000
# PLC_BRTH_STATE_SD        0.000000
# PLC_BRTH_STATE_TN        0.000000
# PLC_BRTH_STATE_TX        0.000000
# PLC_BRTH_STATE_UM        0.000000
# PLC_BRTH_STATE_US        0.000000
# PLC_BRTH_STATE_UT        0.000000
# PLC_BRTH_STATE_VA        0.000000
# PLC_BRTH_STATE_VI        0.000000
# PLC_BRTH_STATE_VT        0.000000
# PLC_BRTH_STATE_WA        0.000000
# PLC_BRTH_STATE_WI        0.000000
# PLC_BRTH_STATE_WV        0.000000
# PLC_BRTH_STATE_WY        0.000000
# PLC_BRTH_STATE_XX        0.000000
# PLC_BRTH_STATE_YN        0.000000
# PLC_BRTH_STATE_YY        0.000000
# PLC_BRTH_STATE_ZZ        0.000000
# dtype: float64

# %%
df.drop(columns=['ICCC3WHO', 'ICCC3XWHO', 'IHS'], inplace=True)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (676128, 322)

# %%
df.head()
# Out:
#    CASENUM   REG  MAR_STAT  RACE  ORIGIN  NHIA  SEX  AGE_DX  YR_BRTH  SEQ_NUM  \
# 0  7000002  1502       2.0   1.0     0.0     0    2    60.0   1932.0      2.0
# 1  7000046  1502       5.0   1.0     0.0     0    2    76.0   1920.0      2.0
# 2  7000058  1502       5.0   1.0     0.0     0    2    70.0   1924.0      2.0
# 3  7000068  1502       2.0   1.0     0.0     0    2    59.0   1917.0      2.0
# 4  7000082  1502       5.0   1.0     0.0     0    2    65.0   1946.0      2.0
#
#    DATE_mo  DATE_yr  LATERAL  HISTO2V  BEHO2V  HISTO3V  BEHO3V  GRADE  \
# 0       11     1992        2     8500       3     8500       3      9
# 1        6     1996        1     8500       3     8500       3      2
# 2        6     1994        2     8500       3     8500       3      3
# 3        3     1977        2     8500       3     8500       3      9
# 4       10     2011        2     8230       2     8230       2      2
#
#    DX_CONF  REPT_SRC  NO_SURG  RADIATN  RAD_BRN  RAD_SURG  REC_NO  TYPEFUP  \
# 0      1.0         1        0        0        9       0.0       1        2
# 1      1.0         1        0        1        9       3.0       1        2
# 2      1.0         1        0        0        9       0.0       1        2
# 3      1.0         1        0        1        9       3.0       1        2
# 4      1.0         1        0        2        9       3.0       1        2
#
#    AGE_REC  SITERWHO  ICDOTO9V  BEHANAL  HISTREC  BRAINREC  CS0204SCHEMA  \
# 0     13.0     26000      1745        3        9        98            13
# 1     16.0     26000      1749        3        9        98            13
# 2     15.0     26000      1748        3        9        98            13
# 3     12.0     26000      1744        3        9        98            13
# 4     14.0     26000      2330        2        5        98            13
#
#    RAC_RECA  RAC_RECY  NHIAREC  HST_STGA  NUMPRIMS  FIRSTPRM  STCOUNTY  \
# 0       1.0       1.0        0         1         1         0      9011
# 1       1.0       1.0        0         1         1         0      9003
# 2       1.0       1.0        0         1         1         0      9003
# 3       1.0       1.0        0         2         1         0      9011
# 4       1.0       1.0        0         0         1         0      9013
#
#    ICD_5DIG  CODKM  STAT_REC  AYA_RECODE  LYMPHOMA_RECODE  DTH_CLASS  \
# 0         0      0         1          36               99          9
# 1         0      0         1          36               99          9
# 2     50060  50060         4          36               99          9
# 3     50060  50060         4          36               99          9
# 4         0      0         1          99               99          9
#
#    O_DTH_CLASS  INTPRIM  ERSTATUS  PRSTATUS  CSSCHEMA  SRV_TIME_MON  \
# 0            9        1         1         1        58           229
# 1            9        1         1         1        58           186
# 2            9        1         4         4        58            18
# 3            9        1         9         9        58           316
# 4            9        9         1         1        58             2
#
#    SRV_TIME_MON_FLAG  SRV_TIME_MON_PA  SRV_TIME_MON_FLAG_PA  HER2  BRST_SUB  \
# 0                  1              229                     1     9         9
# 1                  1              186                     1     9         9
# 2                  1               18                     1     9         9
# 3                  1              316                     1     9         9
# 4                  1                2                     1     4         5
#
#    ANNARBOR  SITEO2V_C501  SITEO2V_C502  SITEO2V_C503  SITEO2V_C504  \
# 0         8         False         False         False         False
# 1         8         False         False         False         False
# 2         8         False         False         False         False
# 3         8         False         False         False          True
# 4         8         False         False         False          True
#
#    SITEO2V_C505  SITEO2V_C506  SITEO2V_C508  SITEO2V_C509  ICDOT10V_C169  \
# 0          True         False         False         False          False
# 1         False         False         False          True          False
# 2         False         False          True         False          False
# 3         False         False         False         False          False
# 4         False         False         False         False          False
#
#    ICDOT10V_C349  ICDOT10V_C419  ICDOT10V_C435  ICDOT10V_C445  ICDOT10V_C500  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
# 2          False          False          False          False          False
# 3          False          False          False          False          False
# 4          False          False          False          False          False
#
#    ICDOT10V_C501  ICDOT10V_C502  ICDOT10V_C503  ICDOT10V_C504  ICDOT10V_C505  \
# 0          False          False          False          False           True
# 1          False          False          False          False          False
# 2          False          False          False          False          False
# 3          False          False          False           True          False
# 4          False          False          False          False          False
#
#    ICDOT10V_C506  ICDOT10V_C508  ICDOT10V_C509  ICDOT10V_C73  ICDOT10V_D035  \
# 0          False          False          False         False          False
# 1          False          False           True         False          False
# 2          False           True          False         False          False
# 3          False          False          False         False          False
# 4          False          False          False         False          False
#
#    ICDOT10V_D045  ICDOT10V_D050  ICDOT10V_D057  ICDOT10V_D059  \
# 0          False          False          False          False
# 1          False          False          False          False
# 2          False          False          False          False
# 3          False          False          False          False
# 4          False          False          False           True
#
#    PLC_BRTH_CNTRY_AGO  PLC_BRTH_CNTRY_ALB  PLC_BRTH_CNTRY_ARG  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_ASM  PLC_BRTH_CNTRY_AUS  PLC_BRTH_CNTRY_AUT  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_BEL  PLC_BRTH_CNTRY_BGD  PLC_BRTH_CNTRY_BGR  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_BHS  PLC_BRTH_CNTRY_BLR  PLC_BRTH_CNTRY_BLZ  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_BMU  PLC_BRTH_CNTRY_BOL  PLC_BRTH_CNTRY_BRA  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_CAN  PLC_BRTH_CNTRY_CHE  PLC_BRTH_CNTRY_CHL  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_CHN  PLC_BRTH_CNTRY_COD  PLC_BRTH_CNTRY_COK  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_COL  PLC_BRTH_CNTRY_CRI  PLC_BRTH_CNTRY_CUB  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_CYP  PLC_BRTH_CNTRY_CZE  PLC_BRTH_CNTRY_DEU  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_DNK  PLC_BRTH_CNTRY_DOM  PLC_BRTH_CNTRY_DZA  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_ECU  PLC_BRTH_CNTRY_EGY  PLC_BRTH_CNTRY_ENG  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_ESP  PLC_BRTH_CNTRY_EST  PLC_BRTH_CNTRY_ETH  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_FIN  PLC_BRTH_CNTRY_FJI  PLC_BRTH_CNTRY_FRA  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_FSM  PLC_BRTH_CNTRY_GBR  PLC_BRTH_CNTRY_GIB  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_GRC  PLC_BRTH_CNTRY_GRL  PLC_BRTH_CNTRY_GTM  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_GUM  PLC_BRTH_CNTRY_GUY  PLC_BRTH_CNTRY_HKG  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_HND  PLC_BRTH_CNTRY_HRV  PLC_BRTH_CNTRY_HTI  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_HUN  PLC_BRTH_CNTRY_IDN  PLC_BRTH_CNTRY_IND  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_IRL  PLC_BRTH_CNTRY_IRN  PLC_BRTH_CNTRY_IRQ  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_ISL  PLC_BRTH_CNTRY_ITA  PLC_BRTH_CNTRY_JAM  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_JOR  PLC_BRTH_CNTRY_JPN  PLC_BRTH_CNTRY_KEN  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_KHM  PLC_BRTH_CNTRY_KIR  PLC_BRTH_CNTRY_KOR  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_LAO  PLC_BRTH_CNTRY_LBN  PLC_BRTH_CNTRY_LBY  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_LKA  PLC_BRTH_CNTRY_LTU  PLC_BRTH_CNTRY_LUX  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_LVA  PLC_BRTH_CNTRY_MAC  PLC_BRTH_CNTRY_MAR  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_MDG  PLC_BRTH_CNTRY_MDV  PLC_BRTH_CNTRY_MEX  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_MHL  PLC_BRTH_CNTRY_MKD  PLC_BRTH_CNTRY_MLT  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_MMR  PLC_BRTH_CNTRY_MNG  PLC_BRTH_CNTRY_MNP  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_MOZ  PLC_BRTH_CNTRY_MWI  PLC_BRTH_CNTRY_MYS  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_NGA  PLC_BRTH_CNTRY_NIC  PLC_BRTH_CNTRY_NIR  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_NLD  PLC_BRTH_CNTRY_NOR  PLC_BRTH_CNTRY_NPL  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_NZL  PLC_BRTH_CNTRY_PAK  PLC_BRTH_CNTRY_PAN  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_PER  PLC_BRTH_CNTRY_PHL  PLC_BRTH_CNTRY_PLW  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_POL  PLC_BRTH_CNTRY_PRI  PLC_BRTH_CNTRY_PRK  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_PRT  PLC_BRTH_CNTRY_PRY  PLC_BRTH_CNTRY_ROU  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_RUS  PLC_BRTH_CNTRY_RWA  PLC_BRTH_CNTRY_SCT  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_SEN  PLC_BRTH_CNTRY_SLV  PLC_BRTH_CNTRY_SOM  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_SWE  PLC_BRTH_CNTRY_SYR  PLC_BRTH_CNTRY_THA  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_TKL  PLC_BRTH_CNTRY_TUN  PLC_BRTH_CNTRY_TUR  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_TWN  PLC_BRTH_CNTRY_TZA  PLC_BRTH_CNTRY_UGA  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_UKR  PLC_BRTH_CNTRY_UMI  PLC_BRTH_CNTRY_URY  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_USA  PLC_BRTH_CNTRY_VEN  PLC_BRTH_CNTRY_VIR  \
# 0                True               False               False
# 1                True               False               False
# 2                True               False               False
# 3                True               False               False
# 4                True               False               False
#
#    PLC_BRTH_CNTRY_VNM  PLC_BRTH_CNTRY_WLS  PLC_BRTH_CNTRY_XAP  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_XCB  PLC_BRTH_CNTRY_XCH  PLC_BRTH_CNTRY_XCR  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_XCZ  PLC_BRTH_CNTRY_XEF  PLC_BRTH_CNTRY_XEN  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_XET  PLC_BRTH_CNTRY_XGR  PLC_BRTH_CNTRY_XIS  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_XMC  PLC_BRTH_CNTRY_XML  PLC_BRTH_CNTRY_XMS  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_XNF  PLC_BRTH_CNTRY_XNI  PLC_BRTH_CNTRY_XOR  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_XPL  PLC_BRTH_CNTRY_XSC  PLC_BRTH_CNTRY_XSD  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_XSE  PLC_BRTH_CNTRY_XSF  PLC_BRTH_CNTRY_XSL  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_XUM  PLC_BRTH_CNTRY_XWF  PLC_BRTH_CNTRY_XYG  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_ZMB  PLC_BRTH_CNTRY_ZWE  PLC_BRTH_CNTRY_ZZA  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_ZZC  PLC_BRTH_CNTRY_ZZE  PLC_BRTH_CNTRY_ZZF  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_ZZN  PLC_BRTH_CNTRY_ZZP  PLC_BRTH_CNTRY_ZZS  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    PLC_BRTH_CNTRY_ZZU  PLC_BRTH_CNTRY_ZZX  PLC_BRTH_STATE_AL  \
# 0               False               False              False
# 1               False               False              False
# 2               False               False              False
# 3               False               False              False
# 4               False               False              False
#
#    PLC_BRTH_STATE_AR  PLC_BRTH_STATE_AS  PLC_BRTH_STATE_AZ  PLC_BRTH_STATE_BC  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_CA  PLC_BRTH_STATE_CD  PLC_BRTH_STATE_CO  PLC_BRTH_STATE_CT  \
# 0              False              False              False              False
# 1              False              False              False               True
# 2              False              False              False              False
# 3              False              False              False               True
# 4              False              False              False               True
#
#    PLC_BRTH_STATE_DC  PLC_BRTH_STATE_DE  PLC_BRTH_STATE_FL  PLC_BRTH_STATE_FM  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_GA  PLC_BRTH_STATE_GU  PLC_BRTH_STATE_HI  PLC_BRTH_STATE_IA  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_ID  PLC_BRTH_STATE_IL  PLC_BRTH_STATE_IN  PLC_BRTH_STATE_KS  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_KY  PLC_BRTH_STATE_LA  PLC_BRTH_STATE_MA  PLC_BRTH_STATE_MD  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False               True              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_ME  PLC_BRTH_STATE_MH  PLC_BRTH_STATE_MI  PLC_BRTH_STATE_MM  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_MN  PLC_BRTH_STATE_MO  PLC_BRTH_STATE_MP  PLC_BRTH_STATE_MS  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_MT  PLC_BRTH_STATE_NB  PLC_BRTH_STATE_NC  PLC_BRTH_STATE_ND  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_NE  PLC_BRTH_STATE_NH  PLC_BRTH_STATE_NJ  PLC_BRTH_STATE_NM  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_NN  PLC_BRTH_STATE_NV  PLC_BRTH_STATE_NY  PLC_BRTH_STATE_OH  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_OK  PLC_BRTH_STATE_ON  PLC_BRTH_STATE_OR  PLC_BRTH_STATE_PA  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_PP  PLC_BRTH_STATE_PR  PLC_BRTH_STATE_PW  PLC_BRTH_STATE_QC  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_RI  PLC_BRTH_STATE_SC  PLC_BRTH_STATE_SD  PLC_BRTH_STATE_TN  \
# 0               True              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_TX  PLC_BRTH_STATE_UM  PLC_BRTH_STATE_US  PLC_BRTH_STATE_UT  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_VA  PLC_BRTH_STATE_VI  PLC_BRTH_STATE_VT  PLC_BRTH_STATE_WA  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_WI  PLC_BRTH_STATE_WV  PLC_BRTH_STATE_WY  PLC_BRTH_STATE_XX  \
# 0              False              False              False              False
# 1              False              False              False              False
# 2              False              False              False              False
# 3              False              False              False              False
# 4              False              False              False              False
#
#    PLC_BRTH_STATE_YN  PLC_BRTH_STATE_YY  PLC_BRTH_STATE_ZZ
# 0              False              False              False
# 1              False              False              False
# 2              False              False              False
# 3              False              False              False
# 4              False              False              False

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# **Encoding**

# %%
df['is_alive'] = (df['STAT_REC'] == 1).astype(int)

# %%
df.drop(columns=['STAT_REC'], inplace=True)

# %% [markdown]
# **Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_features = scaler.fit_transform(df.drop('is_alive', axis=1))
df_scaled = pd.DataFrame(scaled_features, columns=df.drop('is_alive', axis=1).columns)
df_scaled['is_alive'] = df['is_alive'].values
df = df_scaled

# %% [markdown]
# **PCA**

# %%
from sklearn.decomposition import PCA

X = df.drop('is_alive', axis=1)
pca = PCA(n_components=10)
X_pca = pca.fit_transform(X)
df_pca = pd.DataFrame(X_pca, columns=[f'PC{i+1}' for i in range(10)])
df_pca['is_alive'] = df['is_alive'].values
df = df_pca

# %% [markdown]
# **Correlation**

# %%
import numpy as np

corr_matrix = df.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
df = df.drop(columns=to_drop)

# %% [markdown]
# **Univariate**

# %%
from sklearn.feature_selection import SelectKBest, f_classif

X = df.drop('is_alive', axis=1)
y = df['is_alive']

selector = SelectKBest(score_func=f_classif, k=20)  # Choose top 20 features
X_selected = selector.fit_transform(X, y)

selected_features = X.columns[selector.get_support()]
df_selected = df[selected_features.tolist() + ['is_alive']]
df = df_selected
# Out:
# /home/souparno/Documents/breast-cancer/breast_env/lib/python3.12/site-packages/sklearn/feature_selection/_univariate_selection.py:782: UserWarning: k=20 is greater than n_features=10. All the features will be returned.
#   warnings.warn(

# %% [markdown]
# **RFE**

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
rfe = RFE(model, n_features_to_select=20)
X_rfe = rfe.fit_transform(X, y)

selected_rfe = X.columns[rfe.support_]
df_rfe = df[selected_rfe.tolist() + ['is_alive']]
df = df_rfe
# Out:
# /home/souparno/Documents/breast-cancer/breast_env/lib/python3.12/site-packages/sklearn/feature_selection/_rfe.py:300: UserWarning: Found n_features_to_select=20 > n_features=10. There will be no feature selection and all features will be kept.
#   warnings.warn(

# %% [markdown]
# **LDA**

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.model_selection import train_test_split

# %%
X = df.drop('is_alive', axis=1)
y = df['is_alive']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %%
lda = LDA(n_components=1)
X_train = lda.fit_transform(X_train, y_train)
X_test = lda.transform(X_test)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
model = LogisticRegression(solver='lbfgs')
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90     62139
#            1       0.91      0.91      0.91     73087
#
#     accuracy                           0.90    135226
#    macro avg       0.90      0.90      0.90    135226
# weighted avg       0.90      0.90      0.90    135226

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.09553636135062783
# R2 Score 0.6153332002894192

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=10)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=10)

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90     62139
#            1       0.90      0.93      0.91     73087
#
#     accuracy                           0.91    135226
#    macro avg       0.91      0.90      0.90    135226
# weighted avg       0.91      0.91      0.91    135226

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.09444189726827681
# R2 Score 0.6197399412412858

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
base_estimator = DecisionTreeClassifier(max_depth=1)

# %%
adb_clf = AdaBoostClassifier(
    estimator=base_estimator,
    n_estimators=50,
    learning_rate=1.0,
    random_state=42
)

# %%
adb_clf.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1),
#                    random_state=42)

# %%
y_pred = adb_clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.89     62139
#            1       0.89      0.94      0.91     73087
#
#     accuracy                           0.91    135226
#    macro avg       0.91      0.90      0.90    135226
# weighted avg       0.91      0.91      0.91    135226

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.09456021770961205
# R2 Score 0.6192635368140571

# %% [markdown]
# # Random Forrest

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(
    n_estimators=100,
    max_depth=8,
    min_samples_split=5,
    min_samples_leaf=2,
    random_state=42
)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, min_samples_leaf=2, min_samples_split=5,
#                        random_state=42)

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90     62139
#            1       0.90      0.93      0.91     73087
#
#     accuracy                           0.91    135226
#    macro avg       0.91      0.90      0.90    135226
# weighted avg       0.91      0.91      0.91    135226

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.09455282268202861
# R2 Score 0.6192933120907589

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(
    n_neighbors=2,
    weights='distance',
    metric='euclidean'
)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=2, weights='distance')

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86     62139
#            1       0.88      0.88      0.88     73087
#
#     accuracy                           0.87    135226
#    macro avg       0.87      0.87      0.87    135226
# weighted avg       0.87      0.87      0.87    135226

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.13188292192329878
# R2 Score 0.468987715300062

# %% [markdown]
# # SVC

# %%
from sklearn.svm import LinearSVC

model = LinearSVC(C=1.0, max_iter=10000, random_state=42)
model.fit(X_train, y_train)
# Out:
# LinearSVC(max_iter=10000, random_state=42)

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90     62139
#            1       0.91      0.91      0.91     73087
#
#     accuracy                           0.90    135226
#    macro avg       0.90      0.90      0.90    135226
# weighted avg       0.90      0.90      0.90    135226

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.0955585464333782
# R2 Score 0.6152438744593138

# %% [markdown]
# # Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print(f"Gaussian Naive Bayes Accuracy: {accuracy:.2f}")
# Out:
# Gaussian Naive Bayes Accuracy: 0.90

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90     62139
#            1       0.92      0.91      0.91     73087
#
#     accuracy                           0.90    135226
#    macro avg       0.90      0.90      0.90    135226
# weighted avg       0.90      0.90      0.90    135226

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.0963572094123911
# R2 Score 0.6120281445755191

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb

# %%
xgb_clf = xgb.XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    use_label_encoder=False,
    eval_metric='logloss',
    random_state=42
)

# %%
xgb_clf.fit(X_train, y_train)
# Out:
# /home/souparno/Documents/breast-cancer/breast_env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [16:04:00] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_pred = xgb_clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90     62139
#            1       0.90      0.93      0.91     73087
#
#     accuracy                           0.91    135226
#    macro avg       0.91      0.90      0.90    135226
# weighted avg       0.91      0.91      0.91    135226

# %%
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.09434576190969192
# R2 Score 0.6201270198384092

# %% [markdown]
# # MLP

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier(
    hidden_layer_sizes=(100,),  # One hidden layer with 100 neurons
    activation='relu',          # Activation function for the hidden layer
    solver='adam',              # Optimization algorithm
    max_iter=300,               # Maximum number of iterations
    random_state=42
)

# %%
mlp.fit(X_train, y_train)
# Out:
# MLPClassifier(max_iter=300, random_state=42)

# %%
y_pred = mlp.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.90     62139
#            1       0.90      0.93      0.91     73087
#
#     accuracy                           0.91    135226
#    macro avg       0.91      0.90      0.90    135226
# weighted avg       0.91      0.91      0.91    135226

# %%
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.09419786135802287
# R2 Score 0.6207225253724453

# %% [markdown]
# # Ensemble Learning

# %%
from sklearn.ensemble import BaggingClassifier, GradientBoostingClassifier, StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC

# %%
estimators = [
    ('rf', RandomForestClassifier(n_estimators=10, random_state=42)),
    ('linear-svc', LinearSVC(C=1.0, max_iter=10000, random_state=42))
]
stacking_model = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
stacking_model.fit(X_train, y_train)
# Out:
# StackingClassifier(estimators=[('rf',
#                                 RandomForestClassifier(n_estimators=10,
#                                                        random_state=42)),
#                                ('linear-svc',
#                                 LinearSVC(max_iter=10000, random_state=42))],
#                    final_estimator=LogisticRegression())

# %%
y_pred = stacking_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90     62139
#            1       0.91      0.91      0.91     73087
#
#     accuracy                           0.90    135226
#    macro avg       0.90      0.90      0.90    135226
# weighted avg       0.90      0.90      0.90    135226

# %%
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.09565468179196308
# R2 Score 0.6148567958621903

# %% [markdown]
# # Ensemble (Bag, Boost, Stack)

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# Bagging with shallower trees and fewer estimators
bagging = BaggingClassifier(
    estimator=DecisionTreeClassifier(max_depth=3),  # shallower tree
    n_estimators=5,                                 # fewer trees
    random_state=42
)

# Gradient Boosting with fewer estimators and lower learning rate
boosting = GradientBoostingClassifier(
    n_estimators=50,       # fewer estimators
    learning_rate=0.05,    # more stable training
    max_depth=2,           # shallower boosting trees
    random_state=42
)

# Inner stack with lighter models
stack_inner = StackingClassifier(
    estimators=[
        ('rf', RandomForestClassifier(n_estimators=5, max_depth=3, random_state=42)),
        ('nb', GaussianNB())  # Replaces SVC with a very light model
    ],
    final_estimator=LogisticRegression(max_iter=100)
)

# Final ensemble stacking the reduced models
final_ensemble = StackingClassifier(
    estimators=[
        ('bag', bagging),
        ('boost', boosting),
        ('stack', stack_inner)
    ],
    final_estimator=LogisticRegression(max_iter=100)
)

# Fit on training data
final_ensemble.fit(X_train, y_train)

# Evaluate
from sklearn.metrics import accuracy_score
y_pred = final_ensemble.predict(X_test)
print(f"Final Ensemble Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# Final Ensemble Accuracy: 0.9040

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90     62139
#            1       0.91      0.91      0.91     73087
#
#     accuracy                           0.90    135226
#    macro avg       0.90      0.90      0.90    135226
# weighted avg       0.90      0.90      0.90    135226

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.09597266797805155
# R2 Score 0.6135764589640129
