# %%
import pandas as pd

df = pd.read_csv("breast.csv", low_memory=False)

# %%
df.shape
# Out:
# (712319, 149)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    CASENUM   REG  MAR_STAT  RACE  ORIGIN  NHIA  SEX  AGE_DX  YR_BRTH  SEQ_NUM  \
# 0  7000002  1502       2.0   1.0     0.0     0    2    60.0   1932.0      2.0
# 1  7000046  1502       5.0   1.0     0.0     0    2    76.0   1920.0      2.0
# 2  7000058  1502       5.0   1.0     0.0     0    2    70.0   1924.0      2.0
# 3  7000068  1502       2.0   1.0     0.0     0    2    59.0   1917.0      2.0
# 4  7000082  1502       5.0   1.0     0.0     0    2    65.0   1946.0      2.0
#
#    DATE_mo  DATE_yr SITEO2V  LATERAL  HISTO2V  BEHO2V  HISTO3V  BEHO3V  GRADE  \
# 0       11     1992    C505        2     8500       3     8500       3      9
# 1        6     1996    C509        1     8500       3     8500       3      2
# 2        6     1994    C508        2     8500       3     8500       3      3
# 3        3     1977    C504        2     8500       3     8500       3      9
# 4       10     2011    C504        2     8230       2     8230       2      2
#
# ...

# %%
missing_values = df.isnull().sum()
missing_percent = (df.isnull().sum() / len(df)) * 100

# %%
df = df.dropna(thresh=len(df) * 0.8, axis=1)

# %%
df.shape
# Out:
# (712319, 65)

# %%
object_cols = df.select_dtypes(include=['object']).columns.tolist()
object_cols
# Out:
# ['SITEO2V', 'ICDOT10V', 'PLC_BRTH_CNTRY', 'PLC_BRTH_STATE']

# %%
df = pd.get_dummies(df, columns=object_cols, drop_first=True)

# %%
missing_percent = (df.isnull().sum() / len(df)) * 100
missing_percent
# Out:
# CASENUM                  0.000000
# REG                      0.000000
# MAR_STAT                 3.934894
# RACE                     0.307868
# ORIGIN                   0.510165
# NHIA                     0.000000
# SEX                      0.000000
# AGE_DX                   0.005475
# YR_BRTH                  0.005475
# SEQ_NUM                  0.002948
# DATE_mo                  0.000000
# DATE_yr                  0.000000
# LATERAL                  0.000000
# HISTO2V                  0.000000
# BEHO2V                   0.000000
# HISTO3V                  0.000000
# BEHO3V                   0.000000
# GRADE                    0.000000
# DX_CONF                  0.602258
# REPT_SRC                 0.000000
# NO_SURG                  0.000000
# RADIATN                  0.000000
# RAD_BRN                  0.000000
# RAD_SURG                 0.090549
# REC_NO                   0.000000
# TYPEFUP                  0.000000
# AGE_REC                  0.005475
# ...

# %%
df.drop(columns=['ICCC3WHO', 'ICCC3XWHO', 'IHS'], inplace=True)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (676128, 322)

# %%
df['is_alive'] = (df['STAT_REC'] == 1).astype(int)
df.drop(columns=['STAT_REC','CODKM','ICD_5DIG'], inplace=True)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_features = scaler.fit_transform(df.drop('is_alive', axis=1))
df_scaled = pd.DataFrame(scaled_features, columns=df.drop('is_alive', axis=1).columns)
df_scaled['is_alive'] = df['is_alive'].values
df = df_scaled

# %%
df.to_parquet('df_final.parquet', index=False)

# %%
import pandas as pd
df = pd.read_parquet('df_final.parquet')

# %%
X = df.drop('is_alive', axis=1)
y = df['is_alive']

# %%
from sklearn.model_selection import train_test_split
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.10, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.111, random_state=42)
print(f"Training set size: {X_train.shape[0]}")
print(f"Validation set size: {X_val.shape[0]}")
print(f"Test set size: {X_test.shape[0]}")

# %%
# Correlation

def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: 
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
## threshold--Domain expertise
corr_features=correlation(X_train,0.85)

# %%
X_train.drop(corr_features,axis=1,inplace=True)
X_val.drop(corr_features, axis=1,inplace=True)
X_test.drop(corr_features,axis=1,inplace=True)

# %%
X_train.shape,X_test.shape,X_val.shape
# Out:
# ((540969, 282), (67613, 282), (67546, 282))

# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import RFE, SelectKBest, f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt

print("="*60)
print("FINDING COMMON FEATURES FROM RFE AND ANOVA")
print("="*60)
# Out:
# ...
# FINDING COMMON FEATURES FROM RFE AND ANOVA
# ...

# %%
print("\n1. Applying ANOVA F-test...")
anova_selector = SelectKBest(score_func=f_classif, k=20)
X_train_anova = anova_selector.fit_transform(X_train, y_train)

anova_features = X_train.columns[anova_selector.get_support()]
print(f"ANOVA selected features ({len(anova_features)}): {list(anova_features)}")
# Out:
# 1. Applying ANOVA F-test...
# ANOVA selected features (20): ['CASENUM', 'MAR_STAT', 'AGE_DX', 'YR_BRTH', 'HISTO2V', 'BEHO2V', 'GRADE', 'NO_SURG', 'RAD_SURG', 'HST_STGA', 'FIRSTPRM', 'ERSTATUS', 'SRV_TIME_MON', 'SRV_TIME_MON_FLAG', 'HER2', 'SITEO2V_C509', 'ICDOT10V_D059', 'PLC_BRTH_CNTRY_USA', 'PLC_BRTH_STATE_IA', 'PLC_BRTH_STATE_MI']
# /home/souparno/Documents/breast-cancer/breast_env/lib/python3.12/site-packages/sklearn/feature_selection/_univariate_selection.py:110: UserWarning: Features [19 23 24 25 31 33 37 53] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# /home/souparno/Documents/breast-cancer/breast_env/lib/python3.12/site-packages/sklearn/feature_selection/_univariate_selection.py:111: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw

# %%
from sklearn.linear_model import SGDClassifier

print("\n2. Applying RFE (with SGDClassifier)...")

# Lightweight linear classifier
model = SGDClassifier(loss='log_loss', max_iter=500, random_state=42)

# RFE with fewer features and bigger step for speed
rfe_selector = RFE(estimator=model, n_features_to_select=20, step=2)
X_train_rfe = rfe_selector.fit_transform(X_train, y_train)

rfe_features = X_train.columns[rfe_selector.support_]
print(f"RFE selected features ({len(rfe_features)}): {list(rfe_features)}")
# Out:
# 2. Applying RFE (with SGDClassifier)...
# RFE selected features (20): ['AGE_DX', 'YR_BRTH', 'SEQ_NUM', 'REC_NO', 'HST_STGA', 'NUMPRIMS', 'SRV_TIME_MON', 'HER2', 'PLC_BRTH_CNTRY_BLZ', 'PLC_BRTH_CNTRY_CZE', 'PLC_BRTH_CNTRY_DZA', 'PLC_BRTH_CNTRY_LBY', 'PLC_BRTH_CNTRY_MNG', 'PLC_BRTH_CNTRY_SEN', 'PLC_BRTH_CNTRY_USA', 'PLC_BRTH_CNTRY_XGR', 'PLC_BRTH_CNTRY_ZWE', 'PLC_BRTH_STATE_IA', 'PLC_BRTH_STATE_MI', 'PLC_BRTH_STATE_XX']

# %%
print("\n3. Finding common features...")
common_features = list(set(anova_features) & set(rfe_features))
print(f"Common features ({len(common_features)}): {common_features}")
# Out:
# 3. Finding common features...
# Common features (8): ['AGE_DX', 'PLC_BRTH_CNTRY_USA', 'PLC_BRTH_STATE_IA', 'SRV_TIME_MON', 'HER2', 'PLC_BRTH_STATE_MI', 'YR_BRTH', 'HST_STGA']

# %%
if len(common_features) > 0:
    X_train_common = X_train[common_features]
    X_val_common = X_val[common_features]
    X_test_common = X_test[common_features]

    print(f"\nDataset shapes after selecting common features:")
    print(f"X_train_common: {X_train_common.shape}")
    print(f"X_val_common: {X_val_common.shape}")
    print(f"X_test_common: {X_test_common.shape}")
# Out:
# Dataset shapes after selecting common features:
# X_train_common: (540969, 8)
# X_val_common: (67546, 8)
# X_test_common: (67613, 8)

# %%
X_train_common.to_parquet('X_train_common.parquet', index=False)
X_val_common.to_parquet('X_val_common.parquet', index=False)
X_test_common.to_parquet('X_test_common.parquet', index=False)

# %%
X_train_common = pd.read_parquet('X_train_common.parquet')
X_val_common = pd.read_parquet('X_val_common.parquet')
X_test_common = pd.read_parquet('X_test_common.parquet')

# %%
anova_only = list(set(anova_features) - set(rfe_features))
rfe_only = list(set(rfe_features) - set(anova_features))

print(f"\nFeatures selected by ANOVA only ({len(anova_only)}): {anova_only}")
print(f"Features selected by RFE only ({len(rfe_only)}): {rfe_only}")
# Out:
# Features selected by ANOVA only (12): ['GRADE', 'FIRSTPRM', 'MAR_STAT', 'HISTO2V', 'RAD_SURG', 'SRV_TIME_MON_FLAG', 'SITEO2V_C509', 'ICDOT10V_D059', 'BEHO2V', 'ERSTATUS', 'NO_SURG', 'CASENUM']
# Features selected by RFE only (12): ['PLC_BRTH_STATE_XX', 'PLC_BRTH_CNTRY_ZWE', 'PLC_BRTH_CNTRY_BLZ', 'SEQ_NUM', 'PLC_BRTH_CNTRY_SEN', 'PLC_BRTH_CNTRY_LBY', 'PLC_BRTH_CNTRY_XGR', 'PLC_BRTH_CNTRY_MNG', 'PLC_BRTH_CNTRY_DZA', 'PLC_BRTH_CNTRY_CZE', 'NUMPRIMS', 'REC_NO']

# %%
models = {
    'ANOVA_only': LogisticRegression(max_iter=1000, random_state=42),
    'RFE_only': LogisticRegression(max_iter=1000, random_state=42),
    'Common_features': LogisticRegression(max_iter=1000, random_state=42),
    'All_features': LogisticRegression(max_iter=1000, random_state=42)
}

datasets = {
    'ANOVA_only': (X_train[anova_features], X_val[anova_features], X_test[anova_features]),
    'RFE_only': (X_train[rfe_features], X_val[rfe_features], X_test[rfe_features]),
    'Common_features': (X_train_common, X_val_common, X_test_common),
    'All_features': (X_train, X_val, X_test)
}

results = {}

for name, (X_tr, X_val, X_te) in datasets.items():
    print(f"\nTraining {name} model...")
    print(f"Features used: {X_tr.shape[1]}")
    
    # Cross-validation on the training set
    cv_scores = cross_val_score(models[name], X_tr, y_train, cv=5, scoring='accuracy')
    
    # Fit the model on the full training set
    models[name].fit(X_tr, y_train)
    
    # Predict and evaluate on the validation set
    y_pred_val = models[name].predict(X_val)
    val_accuracy = accuracy_score(y_val, y_pred_val)

    # Predict and evaluate on the test set for final, unbiased performance
    y_pred_test = models[name].predict(X_te)
    test_accuracy = accuracy_score(y_test, y_pred_test)

    results[name] = {
        'cv_mean': cv_scores.mean(),
        'cv_std': cv_scores.std(),
        'val_accuracy': val_accuracy,
        'test_accuracy': test_accuracy,
        'n_features': X_tr.shape[1]
    }
    
    print(f"CV Accuracy: {cv_scores.mean():.4f} (+/- {cv_scores.std() * 2:.4f})")
    print(f"Validation Accuracy: {val_accuracy:.4f}")
    print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# Training ANOVA_only model...
# Features used: 20
# CV Accuracy: 0.9424 (+/- 0.0016)
# Validation Accuracy: 0.9419
# Test Accuracy: 0.9407
#
# Training RFE_only model...
# Features used: 20
# CV Accuracy: 0.9428 (+/- 0.0020)
# Validation Accuracy: 0.9433
# Test Accuracy: 0.9414
#
# Training Common_features model...
# Features used: 8
# CV Accuracy: 0.9422 (+/- 0.0017)
# Validation Accuracy: 0.9425
# Test Accuracy: 0.9409
#
# Training All_features model...
# Features used: 282
# CV Accuracy: 0.9441 (+/- 0.0022)
# Validation Accuracy: 0.9442
# Test Accuracy: 0.9426

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
model = LogisticRegression(solver='lbfgs')
model.fit(X_train_common, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_val = model.predict(X_val_common)
val_accuracy = accuracy_score(y_val, y_pred_val)
print(val_accuracy)
print(classification_report(y_val, y_pred_val))
# Out:
# 0.9424836407781364
#               precision    recall  f1-score   support
#
#            0       0.97      0.91      0.94     30996
#            1       0.93      0.97      0.95     36550
#
#     accuracy                           0.94     67546
#    macro avg       0.95      0.94      0.94     67546
# weighted avg       0.94      0.94      0.94     67546

# %%
y_pred_test = model.predict(X_test_common)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(test_accuracy)
print(classification_report(y_test, y_pred_test))
# Out:
# 0.9408841494978776
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93     30952
#            1       0.92      0.97      0.95     36661
#
#     accuracy                           0.94     67613
#    macro avg       0.94      0.94      0.94     67613
# weighted avg       0.94      0.94      0.94     67613

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Assuming X_train, y_train, X_val, y_val are already defined

models_to_test = {
    'model_C_1': LogisticRegression(C=1, random_state=42, max_iter=1000),
    'model_C_0.1': LogisticRegression(C=0.1, random_state=42, max_iter=1000),
    'model_C_10': LogisticRegression(C=10, random_state=42, max_iter=1000)
}

validation_results = {}

for name, model in models_to_test.items():
    # Train the model on the training data
    model.fit(X_train_common, y_train)

    # Make predictions on the validation set
    y_pred_val = model.predict(X_val_common)

    # Calculate accuracy on the validation set
    val_accuracy = accuracy_score(y_val, y_pred_val)

    validation_results[name] = val_accuracy

    print(f"Validation accuracy for {name}: {val_accuracy:.4f}")
# Out:
# Validation accuracy for model_C_1: 0.9425
# Validation accuracy for model_C_0.1: 0.9417
# Validation accuracy for model_C_10: 0.9425

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=10)
model.fit(X_train_common, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=10)

# %%
y_pred_val = model.predict(X_val_common)
val_accuracy = accuracy_score(y_val, y_pred_val)
print(val_accuracy)
print(classification_report(y_val, y_pred_val))
# Out:
# 0.8462677286589879
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83     30996
#            1       0.85      0.87      0.86     36550
#
#     accuracy                           0.85     67546
#    macro avg       0.85      0.84      0.84     67546
# weighted avg       0.85      0.85      0.85     67546

# %%
y_pred_test = model.predict(X_test_common)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(test_accuracy)
print(classification_report(y_test, y_pred_test))
# Out:
# 0.8460651058228447
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83     30952
#            1       0.85      0.87      0.86     36661
#
#     accuracy                           0.85     67613
#    macro avg       0.85      0.84      0.84     67613
# weighted avg       0.85      0.85      0.85     67613

# %%
models_to_test = {
    'DecisionTree_depth_5': DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_split=10, random_state=42),
    'DecisionTree_depth_10': DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_split=10, random_state=42),
}
validation_results = {}
for name, model in models_to_test.items():
    # Train the model on the training data
    model.fit(X_train_common, y_train)
    
    # Make predictions on the validation set
    y_pred_val = model.predict(X_val_common)
    
    # Calculate accuracy on the validation set
    val_accuracy = accuracy_score(y_val, y_pred_val)
    
    validation_results[name] = val_accuracy
    
    print(f"Validation accuracy for {name}: {val_accuracy:.4f}")
best_model_name = max(validation_results, key=validation_results.get)
best_model = models_to_test[best_model_name]

print(f"\nBest model based on validation accuracy: {best_model_name}")
# Out:
# Validation accuracy for DecisionTree_depth_5: 0.8463
# Validation accuracy for DecisionTree_depth_10: 0.8985
#
# Best model based on validation accuracy: DecisionTree_depth_10

# %%
y_pred_test = best_model.predict(X_test_common)
final_test_accuracy = accuracy_score(y_test, y_pred_test)
print(f"Final test accuracy for the best model: {final_test_accuracy:.4f}")
print(classification_report(y_test, y_pred_test))
# Out:
# Final test accuracy for the best model: 0.9400
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93     30952
#            1       0.95      0.94      0.94     36661
#
#     accuracy                           0.94     67613
#    macro avg       0.94      0.94      0.94     67613
# weighted avg       0.94      0.94      0.94     67613

# %% [markdown]
# # AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
base_estimator = DecisionTreeClassifier(max_depth=1)
adb_clf = AdaBoostClassifier(
    estimator=base_estimator,
    n_estimators=50,
    learning_rate=1.0,
    random_state=42
)

# %%
adb_clf.fit(X_train_common, y_train)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1),
#                    random_state=42)

# %%
y_pred_val = adb_clf.predict(X_val_common)
val_accuracy = accuracy_score(y_val, y_pred_val)
print(val_accuracy)
print(classification_report(y_val, y_pred_val))
# Out:
# 0.8801853551653688
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87     30996
#            1       0.88      0.90      0.89     36550
#
#     accuracy                           0.88     67546
#    macro avg       0.88      0.88      0.88     67546
# weighted avg       0.88      0.88      0.88     67546

# %%
y_pred_test = adb_clf.predict(X_test_common)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(test_accuracy)
print(classification_report(y_test, y_pred_test))
# Out:
# 0.878662387410705
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87     30952
#            1       0.88      0.90      0.89     36661
#
#     accuracy                           0.88     67613
#    macro avg       0.88      0.88      0.88     67613
# weighted avg       0.88      0.88      0.88     67613

# %%
models_to_test = {
    'adaboost_1': AdaBoostClassifier(
                                estimator=base_estimator,
                                n_estimators=50,
                                learning_rate=1.0,
                                random_state=42
                            ),
    'adaboost_2': AdaBoostClassifier(
                                estimator=base_estimator,
                                n_estimators=75,
                                learning_rate=2.0,
                                random_state=42
                            ),
    'adaboost_3': AdaBoostClassifier(
                                estimator=base_estimator,
                                n_estimators=100,
                                learning_rate=0.5,
                                random_state=42
                            )
}
validation_results = {}
for name, model in models_to_test.items():
    # Train the model on the training data
    model.fit(X_train_common, y_train)
    
    # Make predictions on the validation set
    y_pred_val = model.predict(X_val_common)
    
    # Calculate accuracy on the validation set
    val_accuracy = accuracy_score(y_val, y_pred_val)
    
    validation_results[name] = val_accuracy
    
    print(f"Validation accuracy for {name}: {val_accuracy:.4f}")
best_model_name = max(validation_results, key=validation_results.get)
best_model = models_to_test[best_model_name]

print(f"\nBest model based on validation accuracy: {best_model_name}")
# Out:
# Validation accuracy for adaboost_1: 0.8802
# Validation accuracy for adaboost_2: 0.7757
# Validation accuracy for adaboost_3: 0.8780
#
# Best model based on validation accuracy: adaboost_1

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(
    n_estimators=100,
    max_depth=8,
    min_samples_split=5,
    min_samples_leaf=2,
    random_state=42
)
model.fit(X_train_common, y_train)
# Out:
# RandomForestClassifier(max_depth=8, min_samples_leaf=2, min_samples_split=5,
#                        random_state=42)

# %%
y_pred_val = model.predict(X_val_common)
val_accuracy = accuracy_score(y_val, y_pred_val)
print(val_accuracy)
print(classification_report(y_val, y_pred_val))
# Out:
# 0.876128860332218
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86     30996
#            1       0.87      0.90      0.89     36550
#
#     accuracy                           0.88     67546
#    macro avg       0.88      0.87      0.87     67546
# weighted avg       0.88      0.88      0.88     67546

# %%
y_pred_test = model.predict(X_test_common)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(test_accuracy)
print(classification_report(y_test, y_pred_test))
# Out:
# 0.8747726029018088
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86     30952
#            1       0.87      0.90      0.89     36661
#
#     accuracy                           0.87     67613
#    macro avg       0.87      0.87      0.87     67613
# weighted avg       0.87      0.87      0.87     67613

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Assuming X_train_common, X_val_common, y_train, and y_val are already defined

models_to_test = {
    'rf_depth_5': RandomForestClassifier(
                    n_estimators=100,
                    max_depth=5,
                    min_samples_split=5,
                    min_samples_leaf=2,
                    random_state=42
                ),
    'rf_depth_10': RandomForestClassifier(
                    n_estimators=100,
                    max_depth=10,
                    min_samples_split=5,
                    min_samples_leaf=2,
                    random_state=42
                ),
    'rf_more_estimators': RandomForestClassifier(
                    n_estimators=200,
                    max_depth=8,
                    min_samples_split=5,
                    min_samples_leaf=2,
                    random_state=42
                )
}
validation_results = {}
for name, model in models_to_test.items():
    # Train the model on the training data
    model.fit(X_train_common, y_train)
    
    # Make predictions on the validation set
    y_pred_val = model.predict(X_val_common)
    
    # Calculate accuracy on the validation set
    val_accuracy = accuracy_score(y_val, y_pred_val)
    
    validation_results[name] = val_accuracy
    
    print(f"Validation accuracy for {name}: {val_accuracy:.4f}")

best_model_name = max(validation_results, key=validation_results.get)
best_model = models_to_test[best_model_name]

print(f"\nBest model based on validation accuracy: {best_model_name}")
# Out:
# Validation accuracy for rf_depth_5: 0.8581
# Validation accuracy for rf_depth_10: 0.8942
# Validation accuracy for rf_more_estimators: 0.8770
#
# Best model based on validation accuracy: rf_depth_10

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(
    n_neighbors=2,
    weights='distance',
    metric='euclidean'
)
model.fit(X_train_common, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=2, weights='distance')

# %%
y_pred_val = model.predict(X_val_common)
val_accuracy = accuracy_score(y_val, y_pred_val)
print(val_accuracy)
print(classification_report(y_val, y_pred_val))
# Out:
# 0.9275308678530186
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92     30996
#            1       0.93      0.93      0.93     36550
#
#     accuracy                           0.93     67546
#    macro avg       0.93      0.93      0.93     67546
# weighted avg       0.93      0.93      0.93     67546

# %%
y_pred_test = model.predict(X_test_common)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(test_accuracy)
print(classification_report(y_test, y_pred_test))
# Out:
# 0.9276618401786638
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92     30952
#            1       0.94      0.93      0.93     36661
#
#     accuracy                           0.93     67613
#    macro avg       0.93      0.93      0.93     67613
# weighted avg       0.93      0.93      0.93     67613

# %% [markdown]
# # SVC

# %%
from sklearn.svm import LinearSVC

model = LinearSVC(C=1.0, max_iter=10000, random_state=42)
model.fit(X_train_common, y_train)
# Out:
# LinearSVC(max_iter=10000, random_state=42)

# %%
y_pred_val = model.predict(X_val_common)
val_accuracy = accuracy_score(y_val, y_pred_val)
print(val_accuracy)
print(classification_report(y_val, y_pred_val))
# Out:
# 0.9354513960856305
#               precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93     30996
#            1       0.91      0.98      0.94     36550
#
#     accuracy                           0.94     67546
#    macro avg       0.94      0.93      0.93     67546
# weighted avg       0.94      0.94      0.94     67546

# %%
y_pred_test = model.predict(X_test_common)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(test_accuracy)
print(classification_report(y_test, y_pred_test))
# Out:
# 0.9342138346176031
#               precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93     30952
#            1       0.91      0.97      0.94     36661
#
#     accuracy                           0.93     67613
#    macro avg       0.94      0.93      0.93     67613
# weighted avg       0.94      0.93      0.93     67613

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

# Assuming X_train_common, X_val_common, y_train, and y_val are already defined

models_to_test = {
    'lsvc_c_0.1': LinearSVC(C=0.1, max_iter=10000, random_state=42),
    'lsvc_c_1.0': LinearSVC(C=1.0, max_iter=10000, random_state=42),
    'lsvc_c_10.0': LinearSVC(C=10.0, max_iter=10000, random_state=42)
}

validation_results = {}
for name, model in models_to_test.items():
    # Train the model on the training data
    model.fit(X_train_common, y_train)
    
    # Make predictions on the validation set
    y_pred_val = model.predict(X_val_common)
    
    # Calculate accuracy on the validation set
    val_accuracy = accuracy_score(y_val, y_pred_val)
    
    validation_results[name] = val_accuracy
    
    print(f"Validation accuracy for {name}: {val_accuracy:.4f}")

best_model_name = max(validation_results, key=validation_results.get)
best_model = models_to_test[best_model_name]

print(f"\nBest model based on validation accuracy: {best_model_name}")
# Out:
# Validation accuracy for lsvc_c_0.1: 0.9354
# Validation accuracy for lsvc_c_1.0: 0.9355
# Validation accuracy for lsvc_c_10.0: 0.9355
#
# Best model based on validation accuracy: lsvc_c_1.0

# %% [markdown]
# # Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train_common, y_train)
# Out:
# GaussianNB()

# %%
y_pred_val = gnb.predict(X_val_common)
val_accuracy = accuracy_score(y_val, y_pred_val)
print(val_accuracy)
print(classification_report(y_val, y_pred_val))
# Out:
# 0.8272288514493826
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80     30996
#            1       0.81      0.90      0.85     36550
#
#     accuracy                           0.83     67546
#    macro avg       0.83      0.82      0.82     67546
# weighted avg       0.83      0.83      0.83     67546

# %%
y_pred_test = gnb.predict(X_test_common)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(test_accuracy)
print(classification_report(y_test, y_pred_test))
# Out:
# 0.8269119843817018
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80     30952
#            1       0.81      0.89      0.85     36661
#
#     accuracy                           0.83     67613
#    macro avg       0.83      0.82      0.82     67613
# weighted avg       0.83      0.83      0.83     67613

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
import numpy as np

# Assuming X_train_common, X_val_common, y_train, and y_val are already defined

models_to_test = {
    'gnb_smoothing_1e-9': GaussianNB(var_smoothing=1e-9),
    'gnb_smoothing_1e-8': GaussianNB(var_smoothing=1e-8),
    'gnb_smoothing_1e-7': GaussianNB(var_smoothing=1e-7)
}

validation_results = {}
for name, model in models_to_test.items():
    # Train the model on the training data
    model.fit(X_train_common, y_train)
    
    # Make predictions on the validation set
    y_pred_val = model.predict(X_val_common)
    
    # Calculate accuracy on the validation set
    val_accuracy = accuracy_score(y_val, y_pred_val)
    
    validation_results[name] = val_accuracy
    
    print(f"Validation accuracy for {name}: {val_accuracy:.4f}")

best_model_name = max(validation_results, key=validation_results.get)
best_model = models_to_test[best_model_name]

print(f"\nBest model based on validation accuracy: {best_model_name}")
# Out:
# Validation accuracy for gnb_smoothing_1e-9: 0.8272
# Validation accuracy for gnb_smoothing_1e-8: 0.8272
# Validation accuracy for gnb_smoothing_1e-7: 0.8272
#
# Best model based on validation accuracy: gnb_smoothing_1e-9

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb
xgb_clf = xgb.XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    use_label_encoder=False,
    eval_metric='logloss',
    random_state=42
)
xgb_clf.fit(X_train_common, y_train)
# Out:
# /home/souparno/Documents/breast-cancer/breast_env/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [21:21:47] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
y_pred_val = xgb_clf.predict(X_val_common)
val_accuracy = accuracy_score(y_val, y_pred_val)
print(val_accuracy)
print(classification_report(y_val, y_pred_val))
# Out:
# 0.9075444882006336
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.90     30996
#            1       0.90      0.94      0.92     36550
#
#     accuracy                           0.91     67546
#    macro avg       0.91      0.90      0.91     67546
# weighted avg       0.91      0.91      0.91     67546

# %%
y_pred_test = xgb_clf.predict(X_test_common)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(test_accuracy)
print(classification_report(y_test, y_pred_test))
# Out:
# 0.9073403043793353
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.90     30952
#            1       0.90      0.94      0.92     36661
#
#     accuracy                           0.91     67613
#    macro avg       0.91      0.90      0.91     67613
# weighted avg       0.91      0.91      0.91     67613

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# Assuming X_train, y_train, X_test, and y_test are already defined

# Initialize the XGBClassifier
xgb_clf = xgb.XGBClassifier(
    use_label_encoder=False,
    eval_metric='logloss',
    random_state=42
)

# Define the grid of hyperparameters to search
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7]
}

# Initialize GridSearchCV
# cv=5 means it will perform 5-fold cross-validation on the training data
grid_search = GridSearchCV(estimator=xgb_clf, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

print("Starting hyperparameter tuning with GridSearchCV...")

# Fit GridSearchCV to the training data
grid_search.fit(X_train, y_train)

# Get the best hyperparameters and best score
print("Best hyperparameters found: ", grid_search.best_params_)
print("Best cross-validation accuracy: {:.4f}".format(grid_search.best_score_))

# The best model is now stored in grid_search.best_estimator_
best_xgb_clf = grid_search.best_estimator_

# --- Final evaluation on the test set ---
# Evaluate the best model on the unseen test data
y_pred_test = best_xgb_clf.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

print(f"\nFinal test accuracy for the best model: {test_accuracy:.4f}")
# Out:
# Starting hyperparameter tuning with GridSearchCV...

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb_model = GradientBoostingClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42
)

gb_model.fit(X_train_common, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_pred_val = gb_model.predict(X_val_common)
val_accuracy = accuracy_score(y_val, y_pred_val)
print(val_accuracy)
print(classification_report(y_val, y_pred_val))
# Out:
# 0.9091878127498297
#               precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90     30996
#            1       0.90      0.94      0.92     36550
#
#     accuracy                           0.91     67546
#    macro avg       0.91      0.91      0.91     67546
# weighted avg       0.91      0.91      0.91     67546

# %%
y_pred_test = gb_model.predict(X_test_common)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(test_accuracy)
print(classification_report(y_test, y_pred_test))
# Out:
# 0.9081981275790159
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.90     30952
#            1       0.90      0.94      0.92     36661
#
#     accuracy                           0.91     67613
#    macro avg       0.91      0.91      0.91     67613
# weighted avg       0.91      0.91      0.91     67613

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score

# Assuming X_train, y_train, X_test, and y_test are already defined

# Initialize the GradientBoostingClassifier
gb_model = GradientBoostingClassifier(random_state=42)

# Define the grid of hyperparameters to search
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7]
}

# Initialize GridSearchCV
# cv=5 means it will perform 5-fold cross-validation on the training data
grid_search = GridSearchCV(estimator=gb_model, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)

print("Starting hyperparameter tuning with GridSearchCV...")

# Fit GridSearchCV to the training data
grid_search.fit(X_train, y_train)

# Get the best hyperparameters and best score
print("Best hyperparameters found: ", grid_search.best_params_)
print("Best cross-validation accuracy: {:.4f}".format(grid_search.best_score_))

# The best model is now stored in grid_search.best_estimator_
best_gb_model = grid_search.best_estimator_

# --- Final evaluation on the test set ---
# Evaluate the best model on the unseen test data
y_pred_test = best_gb_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)

print(f"\nFinal test accuracy for the best model: {test_accuracy:.4f}")

# %% [markdown]
# # Ensemble 1

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import LinearSVC


estimators = [
    ('rf', RandomForestClassifier(
                    n_estimators=100,
                    max_depth=10,
                    min_samples_split=5,
                    min_samples_leaf=2,
                    random_state=42
                )),
    ('linear-svc', LinearSVC(C=1.0, max_iter=10000, random_state=42)),
    ('boost', GradientBoostingClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42
))
]
stacking_model = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
stacking_model.fit(X_train_common, y_train)
# Out:
# StackingClassifier(estimators=[('rf',
#                                 RandomForestClassifier(max_depth=10,
#                                                        min_samples_leaf=2,
#                                                        min_samples_split=5,
#                                                        random_state=42)),
#                                ('linear-svc',
#                                 LinearSVC(max_iter=10000, random_state=42)),
#                                ('boost',
#                                 GradientBoostingClassifier(random_state=42))],
#                    final_estimator=LogisticRegression())

# %%
y_pred_val = stacking_model.predict(X_val_common)
val_accuracy = accuracy_score(y_val, y_pred_val)
print(val_accuracy)
print(classification_report(y_val, y_pred_val))
# Out:
# 0.9382494892369644
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93     30996
#            1       0.92      0.96      0.94     36550
#
#     accuracy                           0.94     67546
#    macro avg       0.94      0.94      0.94     67546
# weighted avg       0.94      0.94      0.94     67546

# %%
y_pred_test = stacking_model.predict(X_test_common)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(test_accuracy)
print(classification_report(y_test, y_pred_test))
# Out:
# 0.9376599174714921
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.93     30952
#            1       0.92      0.96      0.94     36661
#
#     accuracy                           0.94     67613
#    macro avg       0.94      0.94      0.94     67613
# weighted avg       0.94      0.94      0.94     67613

# %% [markdown]
# # Ensemble 2

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier

# Bagging with shallower trees and fewer estimators
bagging = BaggingClassifier(
    estimator=DecisionTreeClassifier(criterion='entropy', max_depth=None, min_samples_split=10, random_state=42),  # shallower tree
    n_estimators=5,                                 # fewer trees
    random_state=42
)

# Gradient Boosting with fewer estimators and lower learning rate
boosting = GradientBoostingClassifier(
    n_estimators=50,       # fewer estimators
    learning_rate=0.05,    # more stable training
    max_depth=2,           # shallower boosting trees
    random_state=42
)

# Inner stack with lighter models
stack_inner = StackingClassifier(
    estimators = [
        ('linear-svc', LinearSVC(C=1.0, max_iter=10000, random_state=42)),
        ('knn', KNeighborsClassifier(
            n_neighbors=7,
            weights='distance',
            metric='euclidean'
        ),
        'logistic-reg', LogisticRegression(C=10, random_state=42, max_iter=1000))
    ],
    final_estimator=LogisticRegression(max_iter=100)
)

# Final ensemble stacking the reduced models
final_ensemble = StackingClassifier(
    estimators=[
        ('bag', bagging),
        ('boost', boosting),
        ('stack', stack_inner)
    ],
    final_estimator=LogisticRegression(max_iter=100)
)

# Fit on training data
final_ensemble.fit(X_train_common, y_train)

# Evaluate
from sklearn.metrics import accuracy_score
y_pred = final_ensemble.predict(X_test_common)
print(f"Final Ensemble Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# Final Ensemble Accuracy: 0.9485

# %%
y_pred_val = final_ensemble.predict(X_val_common)
val_accuracy = accuracy_score(y_val, y_pred_val)
print(val_accuracy)
print(classification_report(y_val, y_pred_val))
# Out:
# 0.9499156130636899
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.95     30996
#            1       0.95      0.96      0.95     36550
#
#     accuracy                           0.95     67546
#    macro avg       0.95      0.95      0.95     67546
# weighted avg       0.95      0.95      0.95     67546

# %%
y_pred_test = final_ensemble.predict(X_test_common)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(test_accuracy)
print(classification_report(y_test, y_pred_test))
# Out:
# 0.9484714477985002
#               precision    recall  f1-score   support
#
#            0       0.95      0.94      0.94     30952
#            1       0.95      0.96      0.95     36661
#
#     accuracy                           0.95     67613
#    macro avg       0.95      0.95      0.95     67613
# weighted avg       0.95      0.95      0.95     67613
